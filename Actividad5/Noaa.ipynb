# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import statsmodels.api as sm
import scipy.stats as stats
from pylab import *
from scipy.io import loadmat

# %%
df=pd.read_csv("Noaa.csv", parse_dates=['Date Time'], header=int(0))

# %%
df.columns= ['Date Time', 'Water Level', 'Sigma', 'O', 'F','R','L','Quality']

# %%
df.dtypes
# Out:
# Date Time      datetime64[ns]
# Water Level           float64
# Sigma                 float64
# O                       int64
# F                       int64
# R                       int64
# L                       int64
# Quality                object
# dtype: object

# %%
df.apply(lambda x: sum(x.isnull()), axis=0)
# Out:
# Date Time      0
# Water Level    0
# Sigma          0
# O              0
# F              0
# R              0
# L              0
# Quality        0
# dtype: int64

# %%
df.head()
# Out:
#             Date Time  Water Level  Sigma  O  F  R  L Quality
# 0 2016-03-09 00:00:00        1.237  0.098  0  0  0  0       v
# 1 2016-03-09 00:06:00        1.250  0.075  0  0  0  0       v
# 2 2016-03-09 00:12:00        1.257  0.118  0  0  0  0       v
# 3 2016-03-09 00:18:00        1.257  0.115  0  0  0  0       v
# 4 2016-03-09 00:24:00        1.348  0.118  0  0  0  0       v

# %%
x=df["Date Time"]
y=df["Water Level"]

plt.title("Marea, Nawiliwili, HI. 10 Marzo 2016")
plt.ylabel('Nivel del mar (mm)')
plt.xlabel('Fecha')
plt.grid(True)


plt.plot(x,y)

# %%
plt.show()

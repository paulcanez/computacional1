# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as mplt
import pylab as plt
from matplotlib import rc
from pylab import figure, show, legend, xlabel, ylabel

# %%
df = pd.read_csv("/home/paulcanez/Documentos/Act4Computacional/Datos16Feb2.csv")

# %%
df.columns=['PRES','HGHT','TEMP','DWPT','RELH','MIXR','DRCT','SKNT','THTA','THTE','THTV']

# %%
df.head(15)
# Out:
#       PRES  HGHT  TEMP  DWPT  RELH   MIXR  DRCT  SKNT   THTA   THTE   THTV
# 0   1010.0    20  27.2  19.2    62  14.06   247     7  299.5  340.8  302.0
# 1   1000.0   107  25.8  19.8    69  14.76   260    11  298.9  342.2  301.6
# 2    925.0   790  19.6  16.2    81  12.68   275    14  299.3  336.6  301.6
# 3    917.0   865  19.2  14.6    75  11.52   278    14  299.7  333.6  301.8
# 4    915.0   884  20.2  11.2    56   9.21   279    14  300.9  328.3  302.6
# 5    913.0   903  21.0   7.0    40   6.93   280    14  301.9  322.9  303.2
# 6    888.0  1142  21.2  -0.8    23   4.08   282    11  304.5  317.3  305.3
# 7    852.0  1498  18.6   0.3    29   4.62   285     6  305.4  319.8  306.2
# 8    850.0  1518  18.4   0.4    30   4.66   285     5  305.4  320.0  306.3
# 9    830.0  1721  16.4   0.4    34   4.77   338     2  305.4  320.3  306.3
# 10   822.0  1803  16.0  -0.5    32   4.52     0     1  305.9  320.0  306.7
# ...

# %%
x=df[u'HGHT']
y=df[u'PRES']

# %%
mplt.plot(x,y)
mplt.grid(True)
plt.xlabel('Altura [m]')
plt.ylabel('Presión [hPa]')

# %%
plt.show()

# %%
x=df[u'HGHT']
y=df[u'TEMP']

# %%
mplt.plot(x,y)
mplt.grid(True)
plt.xlabel('Altura [m]')
plt.ylabel('Temperatura[°C]')

# %%
plt.show()

# %%
x=df[u'HGHT']
y=df[u'DWPT']

# %%
mplt.plot(x,y)
mplt.grid(True)
plt.xlabel('Altura [m]')
plt.ylabel('Temperatura de rocío [°C]')

# %%
plt.show()

# %%
plt.show()

# %%
import os.path

# %%
import tephi as tph

# %%
dew_point = pd.read_csv("/home/paulcanez/Documentos/Act4Computacional/PressVsTR.csv", names=["Presión", "DWPT"])
dry_bulb = pd.read_csv("/home/paulcanez/Documentos/Act4Computacional/PressVsT.csv", names=["Presión", "TEMP"])
tpg = tph.Tephigram()
tpg.plot(dew_point)
tpg.plot(dry_bulb)
plt.show()
